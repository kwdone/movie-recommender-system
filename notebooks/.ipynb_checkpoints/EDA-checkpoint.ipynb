# %%
import zipfile 

zip_path = "../data/ml-1m.zip"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    print(zip_ref.namelist())
# Out:
# ['ml-1m/', 'ml-1m/movies.dat', 'ml-1m/ratings.dat', 'ml-1m/README', 'ml-1m/users.dat']

# %%
zip_path = "../data/ml-1m.zip"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    with zip_ref.open("ml-1m/ratings.dat") as file:
        for _ in range(5):
            print(file.readline().decode('utf-8'))
# Out:
# 1::1193::5::978300760
#
# 1::661::3::978302109
#
# 1::914::3::978301968
#
# 1::3408::4::978300275
#
# 1::2355::5::978824291

# %%
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("../data/")
    print("Complete extraction!")
# Out:
# Complete extraction!

# %%
import pandas as pd 

ratings = pd.read_csv(
    "../data/ml-1m/ratings.dat",
    sep="::",
    engine="python",
    names=["user_id", "movie_id", "rating", "timestamp"]
)

ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies = pd.read_csv(
    "../data/ml-1m/movies.dat",
    sep="::",
    engine="python",
    names=["movie_id", "title", "genres"]
)

movies.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 movies = pd.read_csv(
#       2     "../data/ml-1m/movies.dat",
#       3     sep="::",
#       4     engine="python",
#       5     names=["movie_id", "title", "genres"]
#       6 )
#       8 movies.head()
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\python_parser.py:156, in PythonParser.__init__(self, f, **kwds)
#     150 self._col_indices: list[int] | None = None
#     151 columns: list[list[Scalar | None]]
#     152 (
#     153     columns,
#     154     self.num_original_columns,
#     155     self.unnamed_cols,
# --> 156 ) = self._infer_columns()
#     158 # Now self.columns has the set of columns that we will process.
#     159 # The original set is stored in self.original_columns.
#     160 # error: Cannot determine type of 'index_names'
#     161 (
#     162     self.columns,
#     163     self.index_names,
#    (...)    168     self.index_names,
#     169 )
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\python_parser.py:731, in PythonParser._infer_columns(self)
#     727         columns = self._handle_usecols(
#     728             columns, columns[0], num_original_columns
#     729         )
#     730 else:
# --> 731     ncols = len(self._header_line)
#     732     num_original_columns = ncols
#     734     if not names:
#
# File pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\python_parser.py:759, in PythonParser._header_line(self)
#     756     return None
#     758 try:
# --> 759     line = self._buffered_line()
#     760 except StopIteration as err:
#     761     if not self.names:
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\python_parser.py:822, in PythonParser._buffered_line(self)
#     820     return self.buf[0]
#     821 else:
# --> 822     return self._next_line()
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\python_parser.py:921, in PythonParser._next_line(self)
#     918     next(self.data)
#     920 while True:
# --> 921     orig_line = self._next_iter_line(row_num=self.pos + 1)
#     922     self.pos += 1
#     924     if orig_line is not None:
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\python_parser.py:989, in PythonParser._next_iter_line(self, row_num)
#     987 try:
#     988     assert not isinstance(self.data, list)
# --> 989     line = next(self.data)
#     990     # lie about list[str] vs list[Scalar] to minimize ignores
#     991     return line  # type: ignore[return-value]
#
# File ~\OneDrive\Desktop\dev\venv\Lib\site-packages\pandas\io\parsers\python_parser.py:259, in PythonParser._make_reader.<locals>._read()
#     258 def _read():
# --> 259     line = f.readline()
#     260     pat = re.compile(sep)
#     262     yield pat.split(line.strip())
#
# File <frozen codecs>:325, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 3114: invalid continuation byte
